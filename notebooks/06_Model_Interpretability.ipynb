# %%
import joblib

# Save final tuned classifier
joblib.dump(xgb, "crop_recommendation_model.pkl")

# Save label encoder
joblib.dump(le, "label_encoder.pkl")

# Save feature column order
joblib.dump(X.columns.tolist(), "crop_feature_columns.pkl")

print("Crop Recommendation Model Saved Successfully")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import joblib
#       3 # Save final tuned classifier
# ----> 4 joblib.dump(xgb, "crop_recommendation_model.pkl")
#       6 # Save label encoder
#       7 joblib.dump(le, "label_encoder.pkl")
#
# NameError: name 'xgb' is not defined
